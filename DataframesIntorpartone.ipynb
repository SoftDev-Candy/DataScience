# %%
import pandas as pd
import numpy as np

# %%
 data = {
    "asset": ["AAPL", "MSFT", "BTC", "ETH"],
    "price": [210, 450, 62000, 3400],
    "asset_type": ["stock", "stock", "crypto", "crypto"]
}

# %%
df_assets  =  pd.DataFrame(data)

# %%
df_assets.head()
# Out:
#   asset  price asset_type
# 0  AAPL    210      stock
# 1  MSFT    450      stock
# 2   BTC  62000     crypto
# 3   ETH   3400     crypto

# %%
df_assets.shape
# Out:
# (4, 3)

# %%
df_assets.columns
# Out:
# Index(['asset', 'price', 'asset_type'], dtype='object')

# %%
df_assets.dtypes
# Out:
# asset         object
# price          int64
# asset_type    object
# dtype: object

# %%
data2 = [
    ["rent", 1600],
    ["food", 800],
    ["transport", 150],
    ["gym", 120]
]

# %%
df_expenses = pd.DataFrame(data2,columns=["category", "amount"])

# %%
df_expenses
# Out:
#     category  amount
# 0       rent    1600
# 1       food     800
# 2  transport     150
# 3        gym     120

# %%
df_expenses.columns
# Out:
# Index(['category', 'amount'], dtype='object')

# %%
income = 4000
df_expenses["share_of_income"] = df_expenses["amount"] / income * 100

# %%
df_expenses
# Out:
#     category  amount  share_of_income
# 0       rent    1600            40.00
# 1       food     800            20.00
# 2  transport     150             3.75
# 3        gym     120             3.00
