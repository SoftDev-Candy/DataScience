# %%
import pandas as pd

# %%
https://www.football-data.co.uk/data.php

# %%
df_premier = pd.read_csv('https://www.football-data.co.uk/mmz4281/2526/E0.csv')

# %%
df_premier
# Out:
#     Div        Date   Time       HomeTeam     AwayTeam  FTHG  FTAG FTR  HTHG  \
# 0    E0  15/08/2025  20:00      Liverpool  Bournemouth     4     2   H     1
# 1    E0  16/08/2025  12:30    Aston Villa    Newcastle     0     0   D     0
# 2    E0  16/08/2025  15:00       Brighton       Fulham     1     1   D     0
# 3    E0  16/08/2025  15:00     Sunderland     West Ham     3     0   H     0
# 4    E0  16/08/2025  15:00      Tottenham      Burnley     3     0   H     1
# ..   ..         ...    ...            ...          ...   ...   ...  ..   ...
# 375  E0  24/05/2026  16:00       Man City  Aston Villa     1     2   A     1
# 376  E0  24/05/2026  16:00  Nott'm Forest  Bournemouth     1     1   D     1
# 377  E0  24/05/2026  16:00     Sunderland      Chelsea     2     1   H     1
# 378  E0  24/05/2026  16:00      Tottenham      Everton     1     0   H     1
# 379  E0  24/05/2026  16:00       West Ham        Leeds     3     0   H     0
#
#      HTAG  ... B365CAHH B365CAHA  PCAHH  PCAHA  MaxCAHH  MaxCAHA  AvgCAHH  \
# 0       0  ...     2.03     1.78   2.07   1.85     2.03     1.88     1.94
# 1       0  ...     2.05     1.80   2.02   1.89     2.06     1.80     1.95
# 2       0  ...     1.83     2.03   1.93   2.00     1.84     2.03     1.80
# 3       0  ...     1.95     1.90   1.97   1.95     1.95     1.94     1.86
# 4       0  ...     1.98     1.88   1.99   1.93     1.98     1.91     1.88
# ..    ...  ...      ...      ...    ...    ...      ...      ...      ...
# 375     0  ...     1.83     2.03    NaN    NaN     1.83     2.05     1.78
# 376     0  ...     1.90     1.95    NaN    NaN     1.90     1.95     1.81
# 377     0  ...     1.80     2.05    NaN    NaN     1.80     2.05     1.75
# 378     0  ...     1.93     1.93    NaN    NaN     1.93     1.93     1.85
# 379     0  ...     1.93     1.93    NaN    NaN     1.93     1.93     1.86
#
#      AvgCAHA  BFECAHH  BFECAHA
# 0       1.76     2.14     1.86
# 1       1.74     2.14     1.86
# 2       1.96     1.91     2.08
# 3       1.78     2.02     1.97
# 4       1.83     2.07     1.92
# ..       ...      ...      ...
# 375     1.98     1.90     2.09
# 376     1.91     1.94     2.04
# 377     1.99     1.87     2.12
# 378     1.87     1.96     2.03
# 379     1.89     1.97     2.01
#
# [380 rows x 132 columns]

# %%
df_premier.rename(columns = {'Date' : 'date' , 'HomeTeam':'home_team'})
# Out:
#     Div        date   Time      home_team     AwayTeam  FTHG  FTAG FTR  HTHG  \
# 0    E0  15/08/2025  20:00      Liverpool  Bournemouth     4     2   H     1
# 1    E0  16/08/2025  12:30    Aston Villa    Newcastle     0     0   D     0
# 2    E0  16/08/2025  15:00       Brighton       Fulham     1     1   D     0
# 3    E0  16/08/2025  15:00     Sunderland     West Ham     3     0   H     0
# 4    E0  16/08/2025  15:00      Tottenham      Burnley     3     0   H     1
# ..   ..         ...    ...            ...          ...   ...   ...  ..   ...
# 375  E0  24/05/2026  16:00       Man City  Aston Villa     1     2   A     1
# 376  E0  24/05/2026  16:00  Nott'm Forest  Bournemouth     1     1   D     1
# 377  E0  24/05/2026  16:00     Sunderland      Chelsea     2     1   H     1
# 378  E0  24/05/2026  16:00      Tottenham      Everton     1     0   H     1
# 379  E0  24/05/2026  16:00       West Ham        Leeds     3     0   H     0
#
#      HTAG  ... B365CAHH B365CAHA  PCAHH  PCAHA  MaxCAHH  MaxCAHA  AvgCAHH  \
# 0       0  ...     2.03     1.78   2.07   1.85     2.03     1.88     1.94
# 1       0  ...     2.05     1.80   2.02   1.89     2.06     1.80     1.95
# 2       0  ...     1.83     2.03   1.93   2.00     1.84     2.03     1.80
# 3       0  ...     1.95     1.90   1.97   1.95     1.95     1.94     1.86
# 4       0  ...     1.98     1.88   1.99   1.93     1.98     1.91     1.88
# ..    ...  ...      ...      ...    ...    ...      ...      ...      ...
# 375     0  ...     1.83     2.03    NaN    NaN     1.83     2.05     1.78
# 376     0  ...     1.90     1.95    NaN    NaN     1.90     1.95     1.81
# 377     0  ...     1.80     2.05    NaN    NaN     1.80     2.05     1.75
# 378     0  ...     1.93     1.93    NaN    NaN     1.93     1.93     1.85
# 379     0  ...     1.93     1.93    NaN    NaN     1.93     1.93     1.86
#
#      AvgCAHA  BFECAHH  BFECAHA
# 0       1.76     2.14     1.86
# 1       1.74     2.14     1.86
# 2       1.96     1.91     2.08
# 3       1.78     2.02     1.97
# 4       1.83     2.07     1.92
# ..       ...      ...      ...
# 375     1.98     1.90     2.09
# 376     1.91     1.94     2.04
# 377     1.99     1.87     2.12
# 378     1.87     1.96     2.03
# 379     1.89     1.97     2.01
#
# [380 rows x 132 columns]

# %%
#Read multiple URLs using pandas

# %%
root = "https://www.football-data.co.uk/mmz4281/"

# %% [markdown]
# https://www.football-data.co.uk/mmz4281/2526/E0.csv
# https://www.football-data.co.uk/mmz4281/2526/E1.csv
# https://www.football-data.co.uk/mmz4281/2526/E2.csv
# https://www.football-data.co.uk/mmz4281/2526/E3.csv
# https://www.football-data.co.uk/mmz4281/2526/EC.csv

# %%
# creating list of leagues
leagues = ['E0','E2', 'E3']
frames  = []

#run a smiple for loop with leagues names and save the dataframe created in frames
for league in leagues:
    df = pd.read_csv(root + "2526" + "/" + league + ".csv")
    frames.append(df)

# %%
frames[1].head(3)
# Out:
#   Div        Date   Time   HomeTeam       AwayTeam  FTHG  FTAG FTR  HTHG  \
# 0  E2  01/08/2025  20:00      Luton  AFC Wimbledon     1     0   H     0
# 1  E2  02/08/2025  12:30    Cardiff      Peterboro     2     1   H     0
# 2  E2  02/08/2025  15:00  Blackpool      Stevenage     2     3   A     1
#
#    HTAG  ... B365CAHH B365CAHA  PCAHH  PCAHA  MaxCAHH  MaxCAHA  AvgCAHH  \
# 0     0  ...     1.93     1.93   1.93   1.95     1.98     1.93     1.91
# 1     1  ...     1.85     2.00   1.87   2.03     1.90     2.00     1.85
# 2     2  ...     1.93     1.93   1.94   1.94     1.94     1.93     1.84
#
#    AvgCAHA  BFECAHH  BFECAHA
# 0     1.82     1.94     2.01
# 1     1.88     1.93     2.04
# 2     1.87     1.94     2.04
#
# [3 rows x 132 columns]

# %%
len(frames)
# Out:
# 3

# %% [markdown]
# #now for multiple seasons .
# https://www.football-data.co.uk/mmz4281/2425/E0.csv
# https://www.football-data.co.uk/mmz4281/2324/E0.csv

# %%
#simply use a double forloop in this case to loop through and change season links as well
# creating list of leagues
leagues = ['E0','E2', 'E3']
frames  = []

#run a smiple for loop with leagues names and save the dataframe created in frames
for league in leagues:
    for season in range(15 , 25):
        df = pd.read_csv(root + str(season) + str(season + 1) + "/" + league + ".csv")
        df.insert(1 ,'season',season)
        frames.append(df)

# %%
len(frames)
# Out:
# 30

# %%
frames[13]
# Out:
#     Div  season        Date        HomeTeam        AwayTeam  FTHG  FTAG FTR  \
# 0    E2      18  04/08/2018      Accrington      Gillingham     0     2   A
# 1    E2      18  04/08/2018        Barnsley          Oxford     4     0   H
# 2    E2      18  04/08/2018          Burton        Rochdale     1     2   A
# 3    E2      18  04/08/2018        Coventry      Scunthorpe     1     2   A
# 4    E2      18  04/08/2018  Fleetwood Town   AFC Wimbledon     0     1   A
# ..   ..     ...         ...             ...             ...   ...   ...  ..
# 547  E2      18  04/05/2019        Plymouth      Scunthorpe     3     2   H
# 548  E2      18  04/05/2019      Portsmouth      Accrington     1     1   D
# 549  E2      18  04/05/2019      Shrewsbury         Walsall     0     0   D
# 550  E2      18  04/05/2019        Southend      Sunderland     2     1   H
# 551  E2      18  04/05/2019         Wycombe  Fleetwood Town     1     0   H
#
#      HTHG  HTAG  ... BbAv<2.5 BbAH  BbAHh  BbMxAHH  BbAvAHH  BbMxAHA  BbAvAHA  \
# 0       0     2  ...     1.77   19  -0.25     2.02     1.96     1.90     1.86
# 1       2     0  ...     1.92   18  -0.50     2.02     1.95     1.95     1.87
# 2       0     2  ...     1.72   18  -0.50     2.21     2.13     1.76     1.72
# 3       0     0  ...     1.67   20  -0.25     2.05     1.97     1.91     1.84
# 4       0     0  ...     1.65   18  -0.25     1.93     1.86     2.00     1.94
# ..    ...   ...  ...      ...  ...    ...      ...      ...      ...      ...
# 547     2     1  ...     2.02   18  -0.25     1.95     1.87     2.02     1.96
# 548     0     0  ...     2.15   18  -1.25     1.98     1.93     2.00     1.89
# 549     0     0  ...     1.75   17   0.00     2.01     1.95     1.94     1.88
# 550     1     0  ...     1.84   16   0.00     2.06     2.01     1.87     1.82
# 551     0     0  ...     1.71   18  -0.50     2.20     2.11     1.79     1.73
#
#      PSCH  PSCD  PSCA
# 0    2.38  3.36  3.17
# 1    1.83  3.82  4.44
# 2    2.88  3.28  2.62
# 3    2.59  3.23  2.96
# 4    2.02  3.43  4.05
# ..    ...   ...   ...
# 547  1.88  4.08  3.92
# 548  1.44  4.61  7.60
# 549  2.38  3.76  2.89
# 550  2.97  3.71  2.35
# 551  2.39  3.34  3.20
#
# [552 rows x 63 columns]

# %%
#Simply orgranise all Data in Dictionary

# %%
dict_countries = {
              'Spanish La Liga':'SP1', 'Spanish Segunda Division':'SP2',
              'German Bundesliga':'D1', 
              'English Premier League':'E0', 'English League 1':'E2', 'English League 2':'E3',
             }

# %%
dict_countries['German Bundesliga']
# Out:
# 'D1'

# %%
frames  = []
dict_historical_data = {}
#run a smiple for loop with leagues names and save the dataframe created in frames
for league in dict_countries:
    for season in range(15 , 25):
        df = pd.read_csv(root + str(season) + str(season + 1) + "/" + dict_countries[league] + ".csv")
        df.insert(1 ,'season',season)
        frames.append(df) 
    df_frames = pd.concat(frames)
    dict_historical_data[league] = df_frames # assigning dataframe to a new dictionary

# %%
dict_historical_data['Spanish La Liga']
# Out:
#      Div  season        Date    HomeTeam    AwayTeam  FTHG  FTAG FTR  HTHG  \
# 0    SP1      15    21/08/15      Malaga     Sevilla     0     0   D     0
# 1    SP1      15    22/08/15  Ath Madrid  Las Palmas     1     0   H     1
# 2    SP1      15    22/08/15     Espanol      Getafe     1     0   H     1
# 3    SP1      15    22/08/15   La Coruna    Sociedad     0     0   D     0
# 4    SP1      15    22/08/15   Vallecano    Valencia     0     0   D     0
# ..   ...     ...         ...         ...         ...   ...   ...  ..   ...
# 375  SP1      24  24/05/2025      Getafe       Celta     1     2   A     1
# 376  SP1      24  24/05/2025   Vallecano    Mallorca     0     0   D     0
# 377  SP1      24  25/05/2025      Girona  Ath Madrid     0     4   A     0
# 378  SP1      24  25/05/2025  Villarreal     Sevilla     4     2   H     3
# 379  SP1      24  25/05/2025  Ath Bilbao   Barcelona     0     3   A     0
#
#      HTAG  ... 1XBCH  1XBCD  1XBCA  BFECH  BFECD  BFECA  BFEC>2.5  BFEC<2.5  \
# 0       0  ...   NaN    NaN    NaN    NaN    NaN    NaN       NaN       NaN
# 1       0  ...   NaN    NaN    NaN    NaN    NaN    NaN       NaN       NaN
# 2       0  ...   NaN    NaN    NaN    NaN    NaN    NaN       NaN       NaN
# 3       0  ...   NaN    NaN    NaN    NaN    NaN    NaN       NaN       NaN
# 4       0  ...   NaN    NaN    NaN    NaN    NaN    NaN       NaN       NaN
# ..    ...  ...   ...    ...    ...    ...    ...    ...       ...       ...
# 375     1  ...  4.85   3.88   1.77   5.30    3.9   1.79      2.08      1.89
# 376     0  ...  1.53   4.19   7.29   1.50    4.6   8.20      2.10      1.87
# 377     0  ...  3.48   3.57   2.16   3.50    3.7   2.24      1.60      2.64
# 378     1  ...  1.75   4.42   4.30   1.80    4.3   4.60      1.60      2.62
# 379     2  ...  3.49   4.00   2.03   3.35    4.0   2.18      1.47      3.05
#
#      BFECAHH  BFECAHA
# 0        NaN      NaN
# 1        NaN      NaN
# 2        NaN      NaN
# 3        NaN      NaN
# 4        NaN      NaN
# ..       ...      ...
# 375     1.95     2.03
# 376     1.85     2.14
# 377     2.04     1.94
# 378     2.03     1.95
# 379     2.07     1.91
#
# [3800 rows x 153 columns]
